# %% [markdown]
# ## CVXlab
# A Python-embedded, open-source modeling framework able to generate and to solve convex numerical optimization problems.

# %% [markdown]
# - - -
# PACKAGE LOCAL INSTALLATION and USAGE
#
# Editable local installation:
# 1. Create a virtual environment based on 'environment.yml' file.
# 2. In the cmd, from the package root, run: >>> python setup.py sdist bdist_wheel
# 2. In the cmd, from the package root, run: >>> python -m pip install -e .
# 3. From the virtual environment: >>> import esm
# 4. Use esm APIs (Model class, create_model_dir method)

# %% [markdown]
# - - -
# CREATE/UPDATE ENVIRONMENT BASED ON YML FILE IN PROJECT REPO
#
# In the prompt:
# - From the path where environment.yml is present: >>> conda env create -f environment.yml
# - The environment is named "esm", so type >>> conda activate esm
#
# UPDATE ENVIRONMENT YML FILE (in case of modifications)
#
# In the prompt:
# - activate the working environment: >>> conda activate your_environment_name
# - export environment.yml file based on the working environment: >>> conda env export > environment.yml

# %% [markdown]
# - - -
# IMPORT PACKAGE, DEFINE MODEL NAME AND ROOT PATH

# %%
import cvxlab as cl

model_dir_name = 'pyesm_model'
main_dir_path = r'D:\Politecnico di Milano\DENG-PRIN-MIMO - Documenti\Models\model_physical'

# %% [markdown]
# - - -
# MODEL DIRECTORY GENERATION
#
# Generation of a model directory in a defined path. Notes:
# - Blank .yml or .xlsx files can be generated
# - API_usage_guide.ipynb can be generated as guidance for main APIs
# - Template models can be imported based on the tests model gallery [tbd]

# %%
cl.create_model_dir(
    model_dir_name=model_dir_name,
    main_dir_path=main_dir_path,
    template_file_type='xlsx',
    export_tutorial=True,
)

# %% [markdown]
# - - -
# MODEL GENERATION FROM SCRATCH
#
# Step-by-step model creation with sets, data and problems generation.
#
# - Generation of a Model instance defined by settings files filled by user
# - model_settings_from: select among yml and xlsx
# - use_existing_data=True : model coordinates are loaded and numerical problem initialized (model ready to be run).
# - use_existing_data=False : sets excel file generated only, to be filled by user

# %%
model = cl.Model(
    model_dir_name=model_dir_name,
    main_dir_path=main_dir_path,
    log_level='debug',
    model_settings_from='xlsx',
    multiple_input_files=True,
    use_existing_data=True,
    detailed_validation=True,
)
# Out:
# INFO | Model | Generating 'pyesm_model' model instance.
# DEBUG | Model.core.index | Loading and validating 'structure_sets' data structure from 'xlsx' source.
# DEBUG | Model.file_manager | Excel tab 'structure_sets' loaded from 'model_settings.xlsx'.
# DEBUG | Model.core.index | Loading and validating 'structure_variables' data structure from 'xlsx' source.
# DEBUG | Model.file_manager | Excel tab 'structure_variables' loaded from 'model_settings.xlsx'.
# DEBUG | Model.core.index | Completing data tables with information taken from related Sets.
# DEBUG | Model.core.index | Fetching and validating variables from data tables, generating 'Variable' objects.
# DEBUG | Model.core.index | Fetching 'coordinates_info' to Index.variables.
# INFO | Model | Loading existing sets data and variable coordinates to Index.
# DEBUG | Model.core.index | Loading Sets data to Index.sets.
# DEBUG | Model.file_manager | Excel file 'sets.xlsx' loaded.
# DEBUG | Model.core.index | Loading variable coordinates to Index.data.
# DEBUG | Model.core.index | Loading variable coordinates to Index.variables.
# DEBUG | Model.core.index | Filtering variables coordinates in Index.variables.
# DEBUG | Model.core.index | Validating variables coherence with coordinates.
# DEBUG | Model.core.index | Identifying aggregated dimensions for constants coordinates.
# INFO | Model.core.index | Fetching scenario/s information to Index.
# DEBUG | Model.core.index | Loading tables 'foreign_keys' to Index.data_tables.
# INFO | Model | Loading and validating symbolic problem, initializing numerical problem.
# DEBUG | Model.core.problem | Loading and validating structure of symbolic problem from 'xlsx' file.
# DEBUG | Model.file_manager | Excel tab 'problem' loaded from 'model_settings.xlsx'.
# DEBUG | Model.core.problem | Validating symbolic problem expressions coherence with variables [TBD].
# DEBUG | Model.core | Symbolic problem successfully loaded and validated.
# DEBUG | Model.core | Generating dataframes with cvxpy problems.
# DEBUG | Model.core | Generating data structures for endogenous data tables (cvxpy objects, filters dict for data tables).
# DEBUG | Model.core | Data table 'EE' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'Q_y' | type: {0: 'endogenous', 1: 'exogenous'} | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'CUR_y' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'Q_h' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'CUR_h' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'X_y' | type: {0: 'endogenous', 1: 'exogenous'} | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'X_h' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'VV' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'UU' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'MM' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'MM_h' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'r_v' | type: {0: 'exogenous', 1: 'endogenous'} | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'RR_vue' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'RR_vu_C' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'RR_vu_net' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'RR_tot' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'capacity' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'CC_tot' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'CC_r' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'CC_obj' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Data table 'SOC' | type: endogenous | Generating dataframe and cvxpy variable.
# DEBUG | Model.core | Generating data structures for all variables and constants.
# DEBUG | Model.core | Variable 'v' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'v_yy' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'v_hh' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'v_b' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'u' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'u_yy' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'u_yh' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'u_hy' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'u_hh' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'u_b' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'I_st' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'I_yy' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'I_hh' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'I_b' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'm' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'm_y' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'm_h' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'pl_h' | type: constant | Constant value 'set_length'.
# DEBUG | Model.core | Variable 'pl_y' | type: constant | Constant value 'set_length'.
# DEBUG | Model.core | Variable 'pr_y' | type: constant | Constant value 'arange_1'.
# DEBUG | Model.core | Variable 'pr_h' | type: constant | Constant value 'arange_1'.
# DEBUG | Model.core | Variable 'e' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'e_y' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'e_h' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'E_hist_ex' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_e' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_e_mod' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'E_tot' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'E' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'E_hist' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'E_y' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'E_h' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'dp' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Q_y' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'Q_yy' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'Q_yh' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'Q_y_b' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'CUR_y' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'CUR_yy' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Q_h' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'CUR_h' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_y' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'X_yy' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'X_yy_cap' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'X_yh' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'X_y_b' | type: {0: 'endogenous', 1: 'exogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'X_h' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_h_cap' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_h_st' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_h_st_p' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_h_bev' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'X_h_nst' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'V' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'U' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'M' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'M_yh' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'M_h' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'r_v' | type: {0: 'exogenous', 1: 'endogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'r_v_env_p' | type: {0: 'exogenous', 1: 'endogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'r_v_b_out' | type: {0: 'exogenous', 1: 'endogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'r_v_b_in' | type: {0: 'exogenous', 1: 'endogenous'} | Generating data structure.
# DEBUG | Model.core | Variable 'r_vu' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'r_T' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'r_C' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_vu' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_ve' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_vu_C' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_vu_net' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'r_u' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'r_e' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_u' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_e' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_vu_net_tot_pe' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_vu_net_tot' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_ve_tot_pe' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'R_ve_tot' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'i_tf' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_ti_cap' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_ti' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_t' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_y' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_pe' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_h' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_c_cap' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_c_env' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'i_p' | type: constant | Constant value 'sum_vector'.
# DEBUG | Model.core | Variable 'T_yy' | type: constant | Constant value 'lower_triangular'.
# DEBUG | Model.core.problem | Converting constant values to sparse matrix.
# DEBUG | Model.core | Variable 'T_hh' | type: constant | Constant value 'lower_triangular'.
# DEBUG | Model.core.problem | Converting constant values to sparse matrix.
# DEBUG | Model.core | Variable 'dc' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'co' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'lt_o' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'lt_f' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'lt_o_i' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'sf' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_in' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'av_y_max' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'av_y_min' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'soc_min' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'soc_in_st' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'soc_in_st_p' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'soc_end' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'max_dis_st' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'max_ch_st' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'max_ch_st_p' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'av_h_max' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'av_h_min' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_n_pl' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_n_fi' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_n_bu' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_d_bu' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_d_in' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_h' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_h_st_all' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_h_st' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_h_st_p' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_y' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'er_d' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'er_i' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'c_cap' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'c_ru' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'c_rue' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'c_rv' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'c_rve' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_cap' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_cap_d' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_r_d_tot' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_cap_d_t' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_r_d_tot_t' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_r' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_r_d' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_r_d_pe' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_ru' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_rue' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_rv' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_rve' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_tot' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'C_tot_y' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'SOC' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'SOC_st' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'SOC_st_p' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'SOC_end' | type: endogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_max' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_op_min' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_n_pl_max' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'Cap_n_pl_min' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'share_max' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Variable 'share_min' | type: exogenous | Generating data structure.
# DEBUG | Model.core | Fetching data from 'database.db' to cvxpy exogenous variables.
# DEBUG | Model.core.sql_manager | Connection to 'database.db' opened.
# DEBUG | Model.core | Data table 'v' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'v_yy' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'v_hh' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'v_b' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'u' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'u_yy' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'u_yh' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'u_hy' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'u_hh' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'u_b' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'I_st' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'I_yy' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'I_hh' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'I_b' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'm' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'm_y' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'm_h' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'e' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'e_y' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'e_h' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'E_hist_ex' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core.problem | Converting data to sparse matrix.
# DEBUG | Model.core | Data table 'X_e' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'X_e_mod' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'dp' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Q_y' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Q_yy' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Q_yh' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Q_y_b' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'X_y' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'X_yy' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'X_yy_cap' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'X_yh' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'X_y_b' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_v' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_v_env_p' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_v_b_out' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_v_b_in' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_vu' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_T' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_C' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_u' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'r_e' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'dc' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'co' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'lt_o' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'lt_f' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'lt_o_i' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'sf' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Cap_op_in' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'av_y_max' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'av_y_min' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'soc_min' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'soc_in_st' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'soc_in_st_p' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'soc_end' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'max_dis_st' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'max_ch_st' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'max_ch_st_p' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'av_h_max' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'av_h_min' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'er_d' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'er_i' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'c_cap' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'c_ru' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'c_rue' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'c_rv' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'c_rve' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Cap_op_max' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Cap_op_min' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Cap_n_pl_max' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'Cap_n_pl_min' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'share_max' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core | Data table 'share_min' | Fetching data to cvxpy exogenous variable.
# DEBUG | Model.core.sql_manager | Connection to 'database.db' closed.
# DEBUG | Model.core.problem | Defining cvxpy numerical problems based on symbolic problems.
# DEBUG | Model.core.problem | Defining sub-problem '0'
# DEBUG | Model.core.problem | Processing literal expression: 'E_hist == E_hist_ex'
# DEBUG | Model.core.problem | Processing literal expression: 'E == mult(e, X_e_mod)'
# DEBUG | Model.core.problem | Processing literal expression: 'tran(Q_yy) - u_yy @ tran(X_yy) - u_yh @ tran(X_yh) - E_y @ i_tf - tran(CUR_yy) == 0'
# DEBUG | Model.core.problem | Processing literal expression: 'tran(Q_h) - mult(mult(tran(dp), (u_hy @ tran(X_yy) + E_h @ i_tf)), pl_h / 8760) - u_hh @ tran(X_h) - tran(CUR_h) == 0'
# DEBUG | Model.core.problem | Processing literal expression: 'I_yy @ tran(X_yy) - v_yy @ tran(Q_yy)== 0'
# DEBUG | Model.core.problem | Processing literal expression: 'I_hh @ tran(X_h) - v_hh @ tran(Q_h) == 0'
# DEBUG | Model.core.problem | Processing literal expression: 'Q_yh == mult(Q_h, 8760 / pl_h)'
# DEBUG | Model.core.problem | Processing literal expression: 'M_h == mult(mult(dp, M_yh), 8760 / pl_h)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_yh == mult(X_h, 8760 / pl_h)'
# DEBUG | Model.core.problem | Processing literal expression: 'V == mult(v, Q_y)'
# DEBUG | Model.core.problem | Processing literal expression: 'U == mult(u, X_y)'
# DEBUG | Model.core.problem | Processing literal expression: 'M == mult(m, Q_y)'
# DEBUG | Model.core.problem | Processing literal expression: 'R_u == mult(r_u, X_y)'
# DEBUG | Model.core.problem | Processing literal expression: 'R_e == mult(r_e, X_e)'
# DEBUG | Model.core.problem | Processing literal expression: 'R_vu == mult(mult(tran(r_v_env_p), U), (1 - r_T)) + mult(r_vu, (tran(v) @ I_st @ diag(X_y)))'
# DEBUG | Model.core.problem | Processing literal expression: 'R_vu_C == mult(mult(tran(r_v_env_p), U), (1 - r_C))'
# DEBUG | Model.core.problem | Processing literal expression: 'R_vu_net == R_vu - R_vu_C'
# DEBUG | Model.core.problem | Processing literal expression: 'R_ve == mult(tran(r_v_env_p), E_tot)'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_n_fi == mult(Cap_n_pl, shift(pl_y, dc))'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_n_bu == mult(Cap_n_fi, shift(pl_y, co))'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_d_bu == mult(Cap_n_bu, -weib(lt_o, sf, pr_y, 2))'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_d_in == mult(Cap_op_in, -weib(lt_o_i, sf, pr_y, 1))'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_op == Cap_op_in + (Cap_n_bu + Cap_d_bu + Cap_d_in) @ tran(T_yy)'
# DEBUG | Model.core.problem | Processing literal expression: 'R_vu_net_tot_pe == i_p @ R_vu_net'
# DEBUG | Model.core.problem | Processing literal expression: 'R_ve_tot_pe == i_p @ R_ve'
# DEBUG | Model.core.problem | Processing literal expression: 'C_cap == mult(c_cap, Cap_n_fi)'
# DEBUG | Model.core.problem | Processing literal expression: 'C_cap_d == mult(mult(C_cap, annuity(pl_y, lt_f, er_i)), 1 / pow((1 + er_d),(pl_y-1)))'
# DEBUG | Model.core.problem | Processing literal expression: 'C_ru == mult(c_ru, R_u)'
# DEBUG | Model.core.problem | Processing literal expression: 'C_rue == mult(c_rue, R_e)'
# DEBUG | Model.core.problem | Processing literal expression: 'C_rv == mult(c_rv, R_vu_net_tot)'
# DEBUG | Model.core.problem | Processing literal expression: 'C_rve == mult(c_rve, R_ve_tot)'
# DEBUG | Model.core.problem | Processing literal expression: 'C_r_d == mult(C_r, 1 / pow((1 + er_d),(pl_y-1)))'
# DEBUG | Model.core.problem | Processing literal expression: 'C_r_d_tot == i_pe @ C_r_d_pe'
# DEBUG | Model.core.problem | Processing literal expression: 'X_h_cap <= mult(Cap_op_h, av_h_max)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_h_cap >= mult(Cap_op_h, av_h_min)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_yy_cap <= mult(Cap_op_y, av_y_max)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_yy_cap >= mult(Cap_op_y, av_y_min)'
# DEBUG | Model.core.problem | Processing literal expression: 'Q_y >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'Q_h >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'X_yy >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_n_pl >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'CUR_y >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'CUR_h >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'SOC_st == soc_in_st + T_hh @ (- X_h_st)'
# DEBUG | Model.core.problem | Processing literal expression: 'SOC_st_p == soc_in_st_p + T_hh @ (- X_h_st_p - X_h_bev)'
# DEBUG | Model.core.problem | Processing literal expression: 'SOC <= Cap_op_h_st_all'
# DEBUG | Model.core.problem | Processing literal expression: 'SOC >=  mult(Cap_op_h_st_all, soc_min)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_h_nst >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'SOC_end == soc_end'
# DEBUG | Model.core.problem | Processing literal expression: 'X_h_st <= mult(max_dis_st, i_h @ Cap_op_h_st)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_h_st >= mult(-max_ch_st, i_h @ Cap_op_h_st)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_h_st_p >= mult(-max_ch_st_p, i_h @ Cap_op_h_st_p)'
# DEBUG | Model.core.problem | Processing literal expression: 'X_h_st_p <= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'C_tot == i_ti_cap @ C_cap_d_t @ i_c_cap + i_t @ C_r_d_tot_t @ i_c_env'
# DEBUG | Model.core.problem | Processing literal expression: 'mult(X_y @ i_ti, share_max) - X_y >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'mult(X_y @ i_ti, share_min) - X_y <= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_op <= Cap_op_max'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_op >= Cap_op_min'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_n_pl <= Cap_n_pl_max'
# DEBUG | Model.core.problem | Processing literal expression: 'Cap_n_pl >= Cap_n_pl_min'
# DEBUG | Model.core.problem | Processing literal expression: 'Minimize( C_tot_y @ i_y)'
# DEBUG | Model.core.problem | Defining sub-problem '1'
# DEBUG | Model.core.problem | Processing literal expression: 'r_v_b_out @ diag(Q_y_b) - r_v_b_in @ u_b @ diag(X_y_b) @ tran(I_b) @ v_b == 0'
# DEBUG | Model.core.problem | Processing literal expression: 'r_v_b_out >= 0'
# DEBUG | Model.core.problem | Processing literal expression: 'r_v_b_in >= 0'
# INFO | Model | Numerical problem successfully initialized.
# INFO | Model | Model 'pyesm_model' successfully generated.

# %% [markdown]
# Once sets.xlsx file has filled with sets data:
#
# - load_model_coordinates(): load user defined sets, fill coordinates
# - initialize_blank_data_structure():
#     - generate blank sqlite database with sets and variables (empty numerical values)
#     - generate blank xlsx files for exogenous data to be filled by the user

# %%
model.load_model_coordinates()
model.initialize_blank_data_structure()

# %% [markdown]
# Once exogenous xlsx files has filled:
#
# - load_exogenous_data_to_sqlite_database(): load input data into sqlite database
# - initialize_problems(): load and validate symbolic problem, generate numerical problem

# %%
model.load_exogenous_data_to_sqlite_database()
model.initialize_problems()

# %% [markdown]
# - - -
# MODEL GENERATION FROM EXISTING DATA
#
# If use_existing_data=True, generation of Model instance working with existing database and data input files.
#
# The model is generated and ready to be solved.

# %%
model = cl.Model(
    model_dir_name=model_dir_name,
    main_dir_path=main_dir_path,
    log_level='debug',
    model_settings_from='xlsx',
    use_existing_data=True,
    detailed_validation=True,
)

# %% [markdown]
# - - -
# SAVING/LOADING MODEL INSTANCE
#
# In case model instance generation is taking huge time, it is possible to save/load model instance to avoid regenerating it several times.
#
# Notice that - for unknown reasons - model instance can be loaded only if it has not already solve (i.e. do not save model instance if you run the model!)

# %%
cl.save_model_instance(
    instance=model, # name of the model instance here
    file_name='instance_name'
)

# %%
model = cl.load_model_instance(
    file_name='file_name',
    source_dir_path=r"D:\git_repos\pyesm\tests\models\integrated\1_coupled_model\instances",
)

# %% [markdown]
# - - -
# DATA and SYMBOLIC PROBLEM UPDATE without regenerating Model instance
#
# - initialize_problems(): if symbolic problem has modified, upload it and generates a new numerical model
#
# - update_database_and_problem(): in case of modifications in input data files (but not in sets, nor in variables structures) and symbolic problem, update database and problem
#
# - reinitialize_sqlite_database(): reinitialize sqlite database endogenous variables

# %%
# in case of need for generating only one or more data input files/tabs
model.generate_input_data_files(table_key_list=[])

# %%
# in case of modifications in symbolic problem only,
# update problems dataframe and symbolic problem
model.initialize_problems()

# %%
# in case of modifications in input data files (but not in sets, nor in 
# variables structures) and symbolic problem, update database and problem
model.update_database_and_problem()

# %%
# in case of modifications in input data files (but not in sets, nor in 
# variables structures) and symbolic problem, reinitialize sqlite database for
# endogenous variables
model.reinitialize_sqlite_database(force_overwrite=True)

# %% [markdown]
# - - -
# SOLVE NUMERICAL PROBLEM and ENDOGENOUS DATA EXPORT
#
# - run_model(): run model with various settings
# - load_results_to_database(): once model has successfully solved, load endogenous parameters data to sqlite database.
# - check_model_results(): check model results compared to an existing database (path and name of the database with the expected results in model settings attributes)

# %%
model.run_model(
    verbose=False,
    solver='GUROBI',
    integrated_problems=True,
)

# %%
model.load_results_to_database()

# %%
model.check_model_results()

# %% [markdown]
# - - -
# UTILITIES
#
# - sets(): list of model sets
# - variables(): dictionary with variable name (key) and shape of teh variable (value)
# - variable(name, ...): visual check of variables content in the database
# - set(name): visual check of sets content in the database

# %%
model.variables
model.sets

# %%
model.set('products')

# %%
model.variable(name='L',)
